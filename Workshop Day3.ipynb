# %% [markdown]
# # Day3

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Line plot

# %%
#Line Plot
from matplotlib import pyplot 
roll_no=[1,2,3,4,5,6,7,8]
marks=[23,98,67,56,46,35,78,99]
pyplot.plot(roll_no,marks,'g')
pyplot.show()

# %% [markdown]
# # scatter plot

# %%
#scatter plot
from matplotlib import pyplot
#x-axis values
roll_num = [1,2,3,4,5,6,7,8,9]
#y-axis values
marks = [55,75,96,3,49,68,78,99,100]
pyplot.scatter(roll_num, marks)
pyplot.show()

# %% [markdown]
# # Histogram

# %%
#Histogram
from matplotlib import pyplot
marks=[45,98,78,99,99,97,100]
pyplot.hist(marks,bins=7)
pyplot.show()

# %% [markdown]
# # bar charts

# %%
#bar charts
import numpy as np
import matplotlib.pyplot
city = ("Pune","surat","mumbai","kanpur","bhopal","Delhi")
y_val=np.arange(len(city))
rank=[4,7,1,3,2,5]
pyplot.bar(y_val,rank,align="center")
pyplot.xticks(y_val,city)
pyplot.ylabel("Rank")
pyplot.title("City")

pyplot.show()

# %% [markdown]
# # adding features to charts in matplotlib

# %%
#adding features to charts in matplotlib
#x-axis values
roll_num=[1,2,3,4,5,6,7,8,9]
#y-axis values
marks = [23,34,56,78,98,87,99,98,76]
attendance=[45,76,77,87,65,56,98,99,98]
pyplot.plot(roll_num,marks,color='green',label='marks')
pyplot.plot(roll_num,attendance,color='blue',label='Attendance')
pyplot.legend(loc='upper left',frameon=True)
pyplot.show()

# %%
import numpy as np
import matplotlib.pyplot
city=['Pune','Surat','Mumbai','Kanpur','Bhopal','Assam']
rank=[4,7,1,3,2,5]
explode=[0.2,0,0,0,0,0]
colors=['yellowgreen','pink','purple','grey','red','orange']
pyplot.pie(rank,explode=explode,labels=city,colors=colors,autopct='%1.1f%%',shadow=True,startangle=120)
pyplot.axis('equal')
pyplot.show()

# %%
import numpy as np
import matplotlib.pyplot
Party = ('Shreya','Ayushi','PRATHAM','Tyagi','Modi','Nobita')
rank = [6,7,1,5,2,3]
explode = (0.2,0,0,0,0,0)
colors = ['yellowgreen','pink','purple','grey','red','orange']
pyplot.pie(rank,explode=explode,labels=Party,colors=colors,autopct='%1.1f%%',shadow=True,startangle=120)
pyplot.axis('equal')
pyplot.show()

# %%
class Employee:
    def __init__(self, name, age, salary):
        self.name = name
        self.age = age
        self.salary = salary

# Create instances of the Employee class for five employees
employee1 = Employee("John Doe", 30, 50000)
employee2 = Employee("Jane Smith", 35, 60000)
employee3 = Employee("Michael Johnson", 28, 45000)
employee4 = Employee("Emily Davis", 32, 55000)
employee5 = Employee("David Wilson", 40, 70000)

# Accessing employee data
print("Employee 1:")
print("Name:", employee1.name)
print("Age:", employee1.age)
print("Salary:", employee1.salary)

print("Employee 2:")
print("Name:", employee2.name)
print("Age:", employee2.age)
print("Salary:", employee2.salary)

# ... and so on for employee3, employee4, and employee5
# Out:
# Employee 1:
# Name: John Doe
# Age: 30
# Salary: 50000
# Employee 2:
# Name: Jane Smith
# Age: 35
# Salary: 60000

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[55,75,96,75,36,45,87,99,100]
plt.plot(x,y,'r')
plt.xlabel('X Axias title here')
plt.ylabel('Y Axias title here')
plt.title('sytring title here')
plt.show()

# %%
from matplotlib import pyplot as plt
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')
plt.show()

# %%
import numpy as np 
from scipy.sparse.csgraph import connected_components
from scipy.sparse import csr_matrix
arr=np.array([[0,1,2],[1,0,0],[2,0,0]])
newarr=csr_matrix(arr)
print(connected_components(newarr))
# Out:
# (1, array([0, 0, 0]))

# %% [markdown]
# # Find the shortest path from source to all using vertex dijkstra algo.

# %%
import numpy as np
from scipy.sparse.csgraph import dijkstra
from scipy.sparse import csr_matrix
arr = np.array([[0,1,2],[1,0,0],[2,0,0]])
newarr = csr_matrix(arr)
print(dijkstra(newarr,return_predecessors=True,indices=0))
# Out:
# (array([0., 1., 2.]), array([-9999,     0,     0]))

# %% [markdown]
# # Floyd Warshall Algo

# %%
import numpy as np
from scipy.sparse.csgraph import floyd_warshall
from scipy.sparse import csr_matrix
arr=np.array([[0,1,2],[1,0,0],[2,0,0]])
newarr = csr_matrix(arr)
print(floyd_warshall(newarr,return_predecessors=True))
# Out:
# (array([[0., 1., 2.],
#        [1., 0., 3.],
#        [2., 3., 0.]]), array([[-9999,     0,     0],
#        [    1, -9999,     0],
#        [    2,     0, -9999]]))

# %% [markdown]
# # Write a program to create a series from a list ,array,a dn dictionary.

# %%
import pandas as pd 
import numpy as np
list_data = [10,20,30,40,50]
list_series = pd.Series(list_data)
print("Series from list")
print(list_series)
array_data = np.array([0.5,0.8,1.2,1.5])
array_series = pd.Series(array_data)

print("\nSeries from numpyarray:")
print(array_series)
dict_data = {'A':100,'B':200,'C':300,'D':400}
dict_series= pd.Series(dict_data)
print("\nSeriesfrom dictionary")
print(dict_series)
# Out:
# Series from list
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# Series from numpyarray:
# 0    0.5
# 1    0.8
# 2    1.2
# 3    1.5
# dtype: float64
#
# Seriesfrom dictionary
# A    100
# B    200
# C    300
# D    400
# dtype: int64

# %% [markdown]
# # Write program to count number of missing values in each column.

# %%
import pandas as pd
data = {'Column1':[1,2,3,None,5],'Column2':[6,None,8,9,10],'Column3':[11,12,None,14,15]}
df = pd.DataFrame(data)
print(df.isnull().sum(axis=0))
# Out:
# Column1    1
# Column2    1
# Column3    1
# dtype: int64

# %% [markdown]
# # Remove all the null values from dataset.

# %%
import pandas as pd
df = pd.read_csv("Date1.csv")
new_df = df.dropna()
print(new_df.to_string())
# Out:
#     Duration                Date    Pulse    Maxpulse    Calories
# 0                 60  '2020/12/01'     110          130     409.1
# 1                 60  '2020/12/02'     117          145     479.0
# 2                 60  '2020/12/03'     103          135     340.0
# 3                 45  '2020/12/04'     109          175     282.4
# 4                 45  '2020/12/05'     117          148     406.0
# 5                 60  '2020/12/06'     102          127     300.0
# 6                 60  '2020/12/07'     110          136     374.0
# 7                450  '2020/12/08'     104          134     253.3
# 8                 30  '2020/12/09'     109          133     195.1
# 9                 60  '2020/12/10'      98          124     269.0
# 10                60  '2020/12/11'     103          147     329.3
# 11                60  '2020/12/12'     100          120     250.7
# 12                60  '2020/12/12'     100          120     250.7
# ...

# %%
import pandas as pd
df = pd.read_csv("data.csv")
new_df = df.dropna()
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...
