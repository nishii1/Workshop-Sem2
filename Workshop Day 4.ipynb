# %%
print("Hallo! Guten tag")
# Out:
# Hallo! Guten tag

# %% [markdown]
# # Bellman Ford

# %%
import numpy as np
from scipy.sparse.csgraph import bellman_ford
from scipy.sparse import csr_matrix
arr=np.array([[0,1,2],[1,0,0],[2,0,0]])
newarr = csr_matrix(arr)
print(bellman_ford(newarr,return_predecessors=True,indices=0))
# Out:
# (array([0., 1., 2.]), array([-9999,     0,     0]))

# %%
import seaborn

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv("Light.csv")
print(c)
res = seaborn.scatterplot(x = 'Name', y = 'Age',data = c)
plt.show()
# Out:
#    Name      Age
# 0     2    Tyagi
# 1     3    Nishi
# 2     4   ayushi
# 3     5    Nishi
# 4     6   Khushi
# 5     1  Goodbye

# %% [markdown]
# # Inbuilt dataset of sea born

# %%
import seaborn
seaborn.set(style='whitegrid')
fmri=seaborn.load_dataset('fmri')
seaborn.scatterplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
Seaborn Line plot

# %%
import seaborn
seaborn.set(style='whitegrid')
fmri=seaborn.load_dataset('fmri')
seaborn.lineplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv('Light.csv')
print(c)
res = seaborn.lineplot(x = 'Name', y = 'Age',data = c)
plt.show()
# Out:
#    Name      Age
# 0     2    Tyagi
# 1     3    Nishi
# 2     4   ayushi
# 3     5    Nishi
# 4     6   Khushi
# 5     1  Goodbye

# %% [markdown]
# # Categorical Scatter plot

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
csv = seaborn.load_dataset("tips")
res=seaborn.stripplot(x="tip",y="sex",data=csv,jitter=0.05)
plt.show()

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv('new.csv')
print(c)
res = seaborn.catplot(x = 'total_bill', y = 'sex',data = c)
plt.show()
# Out:
#    total_bill  tip     sex smoker       day  time size
# 0          10    2  female    yes    Sunday    17  Nan
# 1          24    2    male     no  Saturday    18  Nan
# 2          34    3    male    yes    Friday    22  Nan
# 3          23    5  female    yes    Monday    21  Nan
# 4          12    3  female     no   Tuesday    18  Nan

# %% [markdown]
# # Tkinter

# %%
import tkinter
to=tkinter.Tk()
to.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Ophelia 20_06")
root.geometry('350x200')
root.mainloop()

# %%
import tkinter as tk
r = tk.Tk()
button.title("Ophelia 20_06")
button=tk.Button(text='Stop',width=25,command=r.destroy)
button.pack()
r.mainloop()

# %%
import tkinter as tk
from tkinter import *
from tkinter import messagebox
top=tkinter.Tk()
top.title("Rockstar 2023")
def hellocalback():
    messagebox.showinfo("hello Python", "hello world")
B=tkinter.Button(top,text="hello",command=hellocalback)
B.pack()
top.mainloop()

# %%
from tkinter import *
master = Tk()
master.title("Bittle")
w=Canvas(master,width=40,height=60)
w.pack()
canvas_height=20
canvas_width=200
y=int(canvas_height/2)
w.create_line(0,y,canvas_width,y)
mainloop()

# %%
from tkinter import *
master = Tk()
master.title("Vielon Dank")
w=Canvas(master,width=2000,height=20,bg='black')
w.pack()
canvas_height=20
canvas_width=200
y=int(canvas_height/2)
w.create_line(0,y,canvas_width,y)
mainloop()

# %% [markdown]
# # Write a program ro draw colored shapes (line,rectangle,oval)on canvas.¶

# %%
from tkinter import *
master = Tk()
master.title("Nishi")
w=Canvas(master,width=400,height=400)
w.pack()
w.create_oval(50,50,150,100,width=2,fill='red')
mainloop()

# %%
#OVAL
from tkinter import *
master = Tk()
master.title("Nishi")
w=Canvas(master,width=400,height=400)
w.pack()
w.create_rectangle(50,50,150,100,width=2,fill='yellow')
mainloop()

# %%
from tkinter import *
master=Tk()
Label(master,text='First_name').grid(row=0)
Label(master,text='Last_name').grid(row=1)
e1=Entry(master)
e2=Entry(master)
e1.grid(row=0,column=1)
e2.grid(row=1,column=1)
mainloop()
